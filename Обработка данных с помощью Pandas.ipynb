# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv",delimiter=';')

# %%
data.shape
# Out:
# (43, 6)

# %%
data
# Out:
#                                naimenovanie_investora              rayon  \
# 0                                    ОАО «Щекиноазот»      Щекинский р-н
# 1                             ООО «Три Эс Новая Тула»            г. Тула
# 2                                  ООО «Черкизово-МП»    ТОСЭР «Ефремов»
# 3                                    ООО «ВБ Алексин»    ТОСЭР «Алексин»
# 4                                          ООО «ХММР»       ИП «Узловая»
# 5                                    АО МХК «ЕвроХим»    г. Новомосковск
# 6                                 ООО «ЕВРАЗ Узловая»  ОЭЗ ППТ «Узловая»
# 7                       ООО  «Полипласт Новомосковск»  г. Новомосковск
# 8                               ООО «Куриное царство»    ТОСЭР «Ефремов»
# 9                                ООО «Щекинская ГРЭС»      Щекинский р-н
# 10                                    АО «Щекиноазот»      Щекинский р-н
# 11        ООО «Кубаньмасло -  Ефремовский маслозавод»         г. Ефремов
# ...

# %%
data.head(6)
# Out:
#     naimenovanie_investora            rayon  \
# 0         ОАО «Щекиноазот»    Щекинский р-н
# 1  ООО «Три Эс Новая Тула»          г. Тула
# 2       ООО «Черкизово-МП»  ТОСЭР «Ефремов»
# 3         ООО «ВБ Алексин»  ТОСЭР «Алексин»
# 4               ООО «ХММР»     ИП «Узловая»
# 5         АО МХК «ЕвроХим»  г. Новомосковск
#
#                                         naimenovanie sroki_realizatsii  \
# 0  Строительство комплекса  по производству аммиа...        30.06.2024
# 1  Проект комплексного освоения территории в целя...        31.12.2030
# 2  Строительство завода по убою, первичной и посл...        31.12.2023
# 3  Строительство центра обеспечения омниканальной...               NaN
# 4  Локализация производства двигателей внутреннег...        31.12.2022
# 5  Реализации на дочерних, зависимых предприятиях...               NaN
#
#    obem_investitsiy_zaplanirovannyy  rabochie_mesta_zaplanirovannye
# 0                             40000                           386.0
# ...

# %%
data.tail(4)
# Out:
#    naimenovanie_investora            rayon  \
# 39  ООО «НПП ЛИО-продукт»  Узловский район
# 40       ОАО «Щекиноазот»  Щекинский район
# 41          ООО «БИЛАГРО»  Ясногорский р-н
# 42         ООО «САФ-НЕВА»  Узловский район
#
#                                          naimenovanie sroki_realizatsii  \
# 39  Организация производства лиофилизированных про...        30.09.2023
# 40  Организация производства нетканого материала п...        03.06.2023
# 41  Строительство оленеводческого комплекса замкну...        30.12.2023
# 42                 Реконструкция сушильного отделения        01.06.2022
#
#     obem_investitsiy_zaplanirovannyy  rabochie_mesta_zaplanirovannye
# 39                               522                            73.0
# 40                               520                            49.0
# 41                               500                           200.0
# 42                               500                             4.0

# %%
data.rename(columns={data.columns[0]: "Naimenovanie", 
                     data.columns[1]:"Rayon", data.columns[2]:"Raboti", 
                     data.columns[3]:"Sroki", data.columns[4]:"Summa", 
                     data.columns[5]:"Rabochie" },
            inplace=True)

# %%
data.head()
# Out:
#               Naimenovanie            Rayon  \
# 0         ОАО «Щекиноазот»    Щекинский р-н
# 1  ООО «Три Эс Новая Тула»          г. Тула
# 2       ООО «Черкизово-МП»  ТОСЭР «Ефремов»
# 3         ООО «ВБ Алексин»  ТОСЭР «Алексин»
# 4               ООО «ХММР»     ИП «Узловая»
#
#                                               Raboti       Sroki  Summa  \
# 0  Строительство комплекса  по производству аммиа...  30.06.2024  40000
# 1  Проект комплексного освоения территории в целя...  31.12.2030  40000
# 2  Строительство завода по убою, первичной и посл...  31.12.2023  30000
# 3  Строительство центра обеспечения омниканальной...         NaN  22000
# 4  Локализация производства двигателей внутреннег...  31.12.2022  20000
#
#    Rabochie
# 0     386.0
# 1     250.0
# 2    2200.0
# 3   15000.0
# 4     500.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Naimenovanie  43 non-null     object
#  1   Rayon         43 non-null     object
#  2   Raboti        43 non-null     object
#  3   Sroki         41 non-null     object
#  4   Summa         43 non-null     int64
#  5   Rabochie      41 non-null     float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 2.1+ KB

# %%
data = (data
        .dropna()
        .astype({'Rabochie': 'int32','Summa': 'float64'}))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 0 to 42
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Naimenovanie  40 non-null     object
#  1   Rayon         40 non-null     object
#  2   Raboti        40 non-null     object
#  3   Sroki         40 non-null     object
#  4   Summa         40 non-null     float64
#  5   Rabochie      40 non-null     int32
# dtypes: float64(1), int32(1), object(4)
# memory usage: 2.0+ KB

# %%
data.describe()
# Out:
#              Summa     Rabochie
# count     40.00000    40.000000
# mean    5584.75000   227.675000
# std     9798.05393   388.629834
# min      500.00000     4.000000
# 25%      950.00000    50.000000
# 50%     1750.00000    98.500000
# 75%     3925.00000   162.500000
# max    40000.00000  2200.000000

# %%
data["Summa"].sum() , data["Rabochie"].sum()
# Out:
# (223390.0, 9107)

# %%
data["God"] = data['Sroki'].apply(lambda x: int(x.split('.')[2]))

# %%
data.head()
# Out:
#               Naimenovanie              Rayon  \
# 0         ОАО «Щекиноазот»      Щекинский р-н
# 1  ООО «Три Эс Новая Тула»            г. Тула
# 2       ООО «Черкизово-МП»    ТОСЭР «Ефремов»
# 4               ООО «ХММР»       ИП «Узловая»
# 6      ООО «ЕВРАЗ Узловая»  ОЭЗ ППТ «Узловая»
#
#                                               Raboti       Sroki    Summa  \
# 0  Строительство комплекса  по производству аммиа...  30.06.2024  40000.0
# 1  Проект комплексного освоения территории в целя...  31.12.2030  40000.0
# 2  Строительство завода по убою, первичной и посл...  31.12.2023  30000.0
# 4  Локализация производства двигателей внутреннег...  31.12.2022  20000.0
# 6  Строительство производства легирующих добавок ...  31.12.2024  11143.0
#
#    Rabochie   God
# 0       386  2024
# 1       250  2030
# 2      2200  2023
# 4       500  2022
# 6       501  2024

# %%
import seaborn as sns

# %%
sns.barplot(data=data, x="God",y='Summa')
# Out:
# <AxesSubplot:xlabel='God', ylabel='Summa'>
